# %%
import os
if (os.path.basename(os.getcwd()) !='M1Focus'):
    # %cd ..
    # %cd M1Focus
from bmtool import bmplot

bmplot.connection_matrix(config='config.json',sources='cortex',targets='cortex',synaptic_info="1",sids='pop_name',tids='pop_name')

# %%
import os
if (os.path.basename(os.getcwd()) !='M1Focus'):
    # %cd ..
    # %cd M1Focus
from bmtool import bmplot
bmplot.connection_matrix(config='config.json',sources='cortex',targets='cortex',synaptic_info="1",sids='pop_name',tids='pop_name')
# Out:
# /home/kac2cf/M1_1000
# /home/kac2cf/M1_1000/M1Focus

# %%
import os
if (os.path.basename(os.getcwd()) !='M1Focus'):
    # %cd ..
    # %cd M1Focus
from bmtool import bmplot
bmplot.connection_matrix(config='config.json',sources='cortex',targets='cortex',synaptic_info="1",sids='pop_name',tids='pop_name')

# %%
bmplot.connection_matrix(config='config.json',sources='cortex',targets='cortex',synaptic_info="0",sids='pop_name',tids='pop_name')
